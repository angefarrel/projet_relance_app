# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('modele_fiche_patient.xlsx', header=1)
df.head()
# Out:
#       Code_Patient Nom_Patient Prenoms_Patient Sexe  Age  \
# 0  0083/10/23/0087       kadjo         sylvain    M   22
# 1  0083/10/23/0088      kouame            paul    M   23
# 2  0083/10/23/0089        kone          issouf    M   24
# 3  0083/10/23/0090      sansan           marie    f   25
# 4  0083/10/23/0091    oudraogo        ibrahima    M   26
#
#   Situation_matrimoniale Lieu_Habitation  Contact_Téléphonique  \
# 0            celibataire          cocody              44092345
# 1                  marie           abobo              44092346
# 2                divorce         marcory              44092347
# 3                  marie    grand bassam              44092348
# 4                  marie          adjame              44092349
#
#   Date_Dernier_CV Date_prochain_CV Date_dernier_ARV    Date_prochain_ARV  \
# 0      2020-12-21       2020-10-23       2020-10-24  2021-02-26 00:00:00
# 1      2020-12-21       2020-10-28       2020-10-24  2021-02-23 00:00:00
# ...
